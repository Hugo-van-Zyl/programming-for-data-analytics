# %% [markdown]
# # Task Summary:
# The note book should have a nice pie chart of peoples email domains in the csv file at the url
#
# https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download
#
# This csv file has 1000 people. You may download the data or link to it.

# %%
# Import pandas that I can pull in CSV data to a dataframe
import pandas as pd

# Import matplotlib library that I can use for creating charts, in particular pie chart
import matplotlib as plt

# Import seaborn library. I will use their standard selection of color palettes to color my pie chart
import seaborn as sns

# Get CSV data into a pandas dataframe. CSV file is in this root folder so no need to specify filepath
df_peopledata = pd.read_csv("people-1000.csv")

# display first few rows of data to make sure it pulled into dataframe correctly
# display(df_peopledata.head())

# Get / isolate the email addresses only from the larger dataframe
# Split the domain name from the people specific email address using the string split() method
# use .str[1] to keep everything after the delimeter @
df_domains = df_peopledata['Email'].str.split('@').str[1]

# check output if correct
# display(df_domains)

# Now I need to get the total number for each unique domain in the datafrane. I will use the values_count() method for this
df_domain_counts = df_domains.value_counts()

# check output if correct
# display(df_domain_counts) 

# Choose a color palette from seaborn for using in my pie chart
pie_colors = sns.color_palette('hls')

# Now create the pie chart using this data
piechart = df_domain_counts.plot(kind='pie', # make pie chart type
                                 labels=df_domain_counts.index, 
                                 autopct='%1.2f%%', # show % of total on chart
                                 colors= pie_colors, # get colors from seaborn palette above
                                 figsize=(10,8), 
                                 shadow = True, # set shadow = True to make it look nicer. 
                                 textprops={'fontsize': 11, 'weight': 'bold'}, # make text more visible
                                 explode=(0.01, 0.01, 0.01), # create a small seperation between the items
                                 startangle=90) # startangle = 90 to start from the top
                                

# set a title for the pie chart
piechart.set_title('Percentage of domain names across 1000 people sample', fontsize=16, weight='bold')
# no y label here as this is pie chart
piechart.set_ylabel('')

#show pie chart
display(piechart)
# Out:
# <Axes: title={'center': 'Percentage of domain names across 1000 people sample'}>

# %% [markdown]
# ## Task Resources
# ### The following resources were used for completion of this task:
# 1. How to convert CSV file data into pandas - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# 2. How to split the domain name from the people specific email address - https://www.w3schools.com/python/ref_string_split.asp , 2nd resource is Topic 3 notebooks shared by the lecturer
# 3. How to count number of values / items in a specific dataframe colum -  https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
# 4. How to create a pie chart in python - https://www.w3schools.com/python/matplotlib_pie_charts.asp, https://www.datacamp.com/tutorial/python-pie-chart, https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.pie.html .  These resources also have additional information that I used to create labels and assign colors to the chart.
# 5. How to customize your pie chart - https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html, https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html
# 6. How to choose seaborn color palette - https://seaborn.pydata.org/tutorial/color_palettes.html
